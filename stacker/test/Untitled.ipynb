# %%
import pandas as pd

# %%
for file in ['OOF_predictions_2.csv', 'OOF_predictions_3.csv', 'OOF_predictions_4.csv']:
    df = pd.read_csv(file)
    features = [f for f in df.columns if f not in ['id']]
    df[features].to_csv('noid_' + file, index=False)

# %%
pd.read_csv('noid_OOF_predictions_2.csv').head(5)
# Out:
#          RGF_1        RGF_2        RGF_3        RGF_4        RGF_5  \
# 0  1692.596817  1728.208764  1716.437461  1760.796423  1718.913148
# 1  1758.573199  1800.473764  1870.506653  1935.500904  1875.364466
# 2  4210.538831  4266.634594  4288.435522  4053.828274  4000.625688
# 3   994.677878  1004.174953  1045.538791  1041.315194  1060.424415
# 4  3545.268075  3277.834471  3252.729641  3204.661435  3197.349938
#
#          RGF_6        RGF_7        RGF_8        RGF_9       RGF_10   ...     \
# 0  1743.502446  1731.564368  1764.886210  1722.999318  1704.331966   ...
# 1  1801.286804  1822.090995  1757.506106  1735.779151  1791.540176   ...
# 2  4107.608363  4120.433733  4018.080700  4018.720687  4116.808255   ...
# 3  1054.633477  1044.968807  1053.406599  1075.823307  1029.754343   ...
# 4  3217.757177  3118.935759  3108.511961  3135.194411  3272.065575   ...
#
#         RGF_12       RGF_13       RGF_14       RGF_15       RGF_16  \
# ...
